# %%
"""Конспект Git книги 'Чистый Код'."""

# %% [markdown]
# Системы контроля версий представляют собой программные средства, которые регистрируют все изменения в исходном коде и позволяют легко восстановить старые версии
# Git - самая популярная система контроля версий
#
# ### Создание новых проектов Python с использованием Cookiecutter
#
# Установить Cookiecutter  pip install --user cookiecutter
#
# cookiecutter gh:asweigart/cookiecutter-basicpythonproject:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Работа с Git
#
#
#
# 1. Создание нового репозитория git init
#     копирование git clone
# 2. git add ./...  - отметка файлов
# 3. git commit -am "<описание>"
#
# ### Установка Git
# Git уже установлена на моем компьютере.
#
# git version 2.47.1.windows.2
#
# #### Настройка имени пользователя и адреса электронной почты
# Задать ваше имя и адрес электронной почты:
# C:\Users\Al>git config --global user.name "Al Sweigart"
# C:\Users\Al>git config --global user.email al@inventwithpython.com
#
# Для настройки текущей конфигурации Git используйте команду
# git config --list.
#
# ### Работа с Git
# Работа с репозиторием Git состоит из нескольких этапов:
#
# ##### Создание репозитория:
#
# Командой git init для нового проекта
# Или git clone для копирования существующего
# Добавление файлов для отслеживания:
#
# Используется команда git add <имя_файла>
# Можно добавить все файлы: git add .
# ##### Сохранение изменений:
# Команда git commit -am "<сообщение коммита>"
# В сообщении описывается содержание изменений
#
#
# #### Как Git отслеживает статус файлов
#
# ##### Основные состояния файлов
# * Неотслеживаемые (Untracked):
#     Файлы, которые Git не видит
#     Для Git эти файлы не существуют
#     Нужно добавить через git add
#
# * Отслеживаемые (Tracked) файлы имеют три состояния:
#     * Сохраненные (Committed): идентичны последнему коммиту
#     * Измененные (Modified): отличаются от последнего коммита
#     * Индексированные (Staged): помечены для следующего коммита
#
# Важные заметки:
# Команду git status рекомендуется использовать часто
#
# ##### Установка watch:
# Зачем это нужно: Не надо постоянно вводить git status Видишь изменения сразу Удобно следить за репозиторием Как "радар" для Git
#
# Windows: скачать с https://inventwithpython.com/watch.exe
#
# ### .gitignore
#
# ##### Синтаксис .gitignore:
# #Байт-компилируемые / оптимизированные / файлы DLL
# __ pycache __/       # Игнорировать папку
# *.py[cod]            # Игнорировать файлы по маске
# *$py.class           # Конкретный шаблон
#
# Проверить игнорируемые файлы: git ls-files --other --ignored --exclude-standard
# Документация: https://git-scm.com/docs/gitignore
#
# ### Сохранение изменений в Git
#
# #### Частота сохранения изменений
# Код следует сохранять при завершении блока функциональности, класса или исправления ошибки. Не сохраняйте код, содержащий синтаксические ошибки или
# очевидно неработоспособный. Коммиты могут состоять из нескольких строк или
# нескольких сотен строк измененного кода, но в любом случае вы должны иметь
# возможность вернуться к более ранней копии и все еще иметь в распоряжении
# рабочую программу. Всегда выполняйте все модульные тесты перед сохранением.
# В идеале все тесты должны проходить (а если они не проходят, упомяните об этом
# в сопроводительном сообщении).
#
# ### Удаление изменение файлов в Git
# Как и при удалении файлов git rm, вы не должны переименовывать или перемещать файлы
# в репозитории в обход Git. В противном случае Git решит, что вы просто удалили
# файл, и создаст новый файл с прежним содержимым. Вместо этого используйте
# команду git mv с последующей командой git commit.
